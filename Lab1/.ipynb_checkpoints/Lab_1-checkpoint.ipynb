# %% [markdown]
# EE21S061 Arihant Jain Lab 1 for EE5175 course:

# %%
# !pip install numpy
# !pip install pillow
# !pip install matplotlib
# Out:
# Requirement already satisfied: numpy in c:\python310\lib\site-packages (1.22.1)
# Requirement already satisfied: pillow in c:\python310\lib\site-packages (9.0.0)
# Requirement already satisfied: matplotlib in c:\python310\lib\site-packages (3.5.1)
# Requirement already satisfied: numpy>=1.17 in c:\python310\lib\site-packages (from matplotlib) (1.22.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib) (4.29.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\python310\lib\site-packages (from matplotlib) (9.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python310\lib\site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# Setting up the environment we will be using pillow to access the image and numpy to perform the arthimetic operation on the image and also going to be using matplotlib to visualize the changes done to the image.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = [18, 7]

# %% [markdown]
# Setting up preferred size of the graph we will be using to visualize the images.

# %%
from PIL import Image
from numpy import asarray

# load the image
pisa = Image.open('pisa_rotate.png')
lena = Image.open('lena_translate.png')
cells = Image.open('cells_scale.png')

# %% [markdown]
# Loading in the image as they are in the same directory we can easily load then using Image object from pillow library as given above

# %%
import math
import numpy as np

# %% [markdown]
# Q2.Rotate the given image (pisa rotate.png) about the image centre, so as to straighten the
# Pisa tower.

# %%
theta = np.radians(-4)
c, s = np.cos(theta), np.sin(theta)
#Calculating the argument in the Rotaion Matrix

# %% [markdown]
# We have now imported the numpy and math to operate on the image. Also calculated the Rotation matrix element assuming the angle of 4 degrees.
# I read online that leaning tower of pisa is tilted at a 3.99 degree so for this task i will be assuming the correction angle to be 4 degrees but it can be changed if neccessary to see how it would affect the image.

# %%
#PISA Image Rotation 
source=pisa
#I used data as a placeholder for all the operation and data2 and data3 as post processed images so changing source name here with any other image should work

# %% [markdown]
# We have loaded the image using Image function from pillow library to work on it i decided to change it to a numpy array
# so the idea is that before processing the image its changed to numpy array and after the operation it is changed back into a PIL image object to be displayed.

# %%
type(pisa)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %% [markdown]
# The first task i decided to tackle was Rotation so here the first approach is to go from source to target.
#
# The issue we would face is non-integer values as output, As pixels are equally spaced we need to assign a pixel fractional co-ordinate to another pixel co-ordinate in target which is close to it.
#
# We can do this in 2 ways assign the fraction pixel to ceil of the co-ordinates or floor of the co-ordinate here we have done both.

# %%
data = asarray(source)
#casting the image as a numpy array and storing it in data
print(type(data))
print(data.shape)
#Looking at the type and shape of the numpy array we obtained shape gives us the image dimension which are then fed into the algorithm to avoid out of bound pixel locations.

#Created another numpy array of same size as the image filled with zeros 
data2=np.zeros_like(data)
data3=np.zeros_like(data)
data4=np.zeros_like(data)
for xs in range(data.shape[0]):
    for ys in range(data.shape[1]):
        #iterating through each pixel in the source image and checking for valid co-ordinates
        #valid co-ordinates are those who fall under the dimension of target image otherwise they are outside the view.
        if not ((math.floor(c*xs+s*ys)>data.shape[0]-1) or (math.floor(-s*xs+c*ys)>data.shape[1]-1)):
            data2[math.floor(c*xs+s*ys)][math.floor(-s*xs+c*ys)]=data[xs][ys]
        #using floor to resolve fractional co-ordinate issue here
        #similarly for ceil we can do the same 
        #using ceil to resolve fractional co-ordinate issue here
        if not ((math.ceil(c*xs+s*ys)>data.shape[0]-1) or (math.ceil(-s*xs+c*ys)>data.shape[1]-1)):
            data3[math.ceil(c*xs+s*ys)][math.ceil(-s*xs+c*ys)]=data[xs][ys]

image=Image.fromarray(data)
image2 = Image.fromarray(data2)
image3 = Image.fromarray(data3)
#converted back the image from numpy array to Pillow image object to visualize.


figure, axis = plt.subplots(1, 3)
axis[0].imshow(image,cmap="gray")
axis[0].set_title('Original')
axis[1].imshow(image2,cmap="gray")
axis[1].set_title('Using Floor')
axis[2].imshow(image3,cmap="gray")
axis[2].set_title('Using ceil')
#setting up a 1*3 plot to show original, floor image,ceil image.
# Out:
# <class 'numpy.ndarray'>
# (482, 207)
# Text(0.5, 1.0, 'Using ceil')

# %% [markdown]
# Looking at the result of Source to Target Transformation we can see that that there are dots spread accross the 3 image this is because of the fact that we are trying to assign a pixel to a nearby pixel based on ceil or floor approach so during these transformation we might skip certain pixel and this is the reason behind the black dots over the images.
#
# Also we can see a that there are a bunch of undefined pixel in the bottom right side of the image as these pixel are based on pixels outside the scope of the original image enough information is not known to account for them.

# %%
total_pixels=data.shape[0]*data.shape[1]
base_zeros=np.count_nonzero(data==0)
holes2=np.count_nonzero(data2==0)-base_zeros
holes3=np.count_nonzero(data3==0)-base_zeros
holes4=np.count_nonzero(data3==0)-base_zeros
print("total number of pixels in the image = ",total_pixels)
print("number of undefined pixels (for floor) = ",holes2," loss in image data (approx) = " ,holes2/total_pixels*100,"%")
print("number of undefined pixels (for ceil) = ",holes3," loss in image data (approx) = " ,holes3/total_pixels*100,"%")
#calculated the number of unassigned pixel in the target image and then saw the loss in data which is to say how many pixels now dont have information.
# Out:
# total number of pixels in the image =  99774
# number of undefined pixels (for floor) =  8223  loss in image data (approx) =  8.24162607492934 %
# number of undefined pixels (for ceil) =  8695  loss in image data (approx) =  8.714695211177261 %

# %% [markdown]
# Just checking up the stats of the image data we have after post processing.

# %%
def bilin(xs,ys):
        #This function takes fraction co-ordinate for source image based on target to source matrix and then uses bilinear interpolation to calculated the value of the given target co-ordinate
        xs_f=math.floor(xs)
        ys_f=math.floor(ys)
        a=ys-ys_f
        b=xs-xs_f
        #Above we calculate all necessary values to perform bilinear interpolation
        if (xs<0 or ys<0 or xs>data.shape[0]-1 or ys>data.shape[1]-1):
            #to account for the fact that this function may sometimes receive invalid co-ordinate such as negative or beyond image dimensions
            return False
        return (((1-a)*(1-b)*data[xs_f][ys_f])+
                ((a)*(1-b)*data[xs_f+1][ys_f])+
                ((1-a)*(b)*data[xs_f][ys_f+1])+
                ((a)*(b)*data[xs_f+1][ys_f+1]))

# %% [markdown]
# Defined a bilin function this function takes in input as the source fractional co-ordinate of the original image which is then used to interpolate for the target pixel based on the distance of the position fractional co-ordinate.

# %%
source=pisa
data = asarray(source)
print(type(data))
print(data.shape)
#again we open the image but this time we iterate through the target co-ordinates

data2=np.zeros_like(data)
for xt in range(data.shape[0]):
    for yt in range(data.shape[1]):
        #This time we are iterating through target pixel which means all pixel in the target image are accounted for. This takes care of the black dot issue in the previous image.
        xs=c*xt-s*yt
        ys=s*xt+c*yt
        #based on the rotation matrix we calculate for source co-ordinate and then pass it to bilin function we created before.
        temp=bilin(xs,ys)
        if (temp):
            data2[xt][yt]=temp
        
image=Image.fromarray(data)
image2 = Image.fromarray(data2)
#converted back the image from numpy array to Pillow image object to visualize.

figure, axis = plt.subplots(1, 2)
axis[0].imshow(image,cmap="gray")
axis[0].set_title('Original')
axis[1].imshow(image2,cmap="gray")
axis[1].set_title('Bilinear Interpolation')
#setting up a 1*2 plot to show original, floor image,ceil image.
# Out:
# <class 'numpy.ndarray'>
# (482, 207)
# Text(0.5, 1.0, 'Bilinear Interpolation')

# %% [markdown]
# Based on Bilinear approach we can see much improvement from the source to target method. This tackles the issue of undefined valus in target image and also account for better quality as each pixel is evaluated based on its distance from the calculated fraction co-ordinate system. This handles issue of insufficent information by using its neighbouring cells to get better quality

# %%
total_pixels=data.shape[0]*data.shape[1]
base_zeros=np.count_nonzero(data==0)
holes2=np.count_nonzero(data2==0)-base_zeros
print("total number of pixels in the image = ",total_pixels)
print("number of undefined pixels (for floor) = ",holes2," loss in image data (approx) = " ,holes2/total_pixels*100,"%")
#calculated the number of unassigned pixel in the target image and then saw the loss in data which is to say how many pixels now dont have information.
# Out:
# total number of pixels in the image =  99774
# number of undefined pixels (for floor) =  9434  loss in image data (approx) =  9.455369134243389 %

# %% [markdown]
# This is similar to data loss in ceil and floor basic rotation but here we get more quality also the data loss metric of the above images has issue because of un-accounted loss in image in the bottom right side of the image.

# %% [markdown]
# Q1.Translate the given image (lena translate.png) by (tx = 3.75, ty = 4.3) pixels?

# %% [markdown]
# Starting again from Source to Target as the first step

# %%
tx=3.75
ty=4.3
#setting up the translation matrix

# %%
source=lena
data = asarray(source)
print(type(data))
print(data.shape)
#again opening up the image and making zero filled array of its size to store post processed image
data2=np.zeros_like(data)
data3=np.zeros_like(data2)
for xs in range(data.shape[0]):
    for ys in range(data.shape[1]):
        #iterating through source co-ordinates.
        xt=xs+tx
        yt=ys+ty
        #adding translation to source co-ordinate
        if (xt<0 or yt<0 or xt>data.shape[0]-1 or yt>data.shape[1]-1):
            #to check for out of bounds issue as shifting would make some pixel move out of dimenstion of the image.
            continue
        
        #using ceil to resolve fractional co-ordinate issue here
        data2[math.ceil(xt)][math.ceil(yt)]=data[xs][ys]
        
        #using floor to resolve fractional co-ordinate issue here
        data3[math.floor(xt)][math.floor(yt)]=data[xs][ys]
        
image=Image.fromarray(data)
image2 = Image.fromarray(data2)
image3 = Image.fromarray(data3)
#converted back the image from numpy array to Pillow image object to visualize.

figure, axis = plt.subplots(1, 3)
axis[0].imshow(image,cmap="gray")
axis[0].set_title('Original')
axis[1].imshow(image2,cmap="gray")
axis[1].set_title('ceil')
axis[2].imshow(image3,cmap="gray")
axis[2].set_title('floor')
#setting up a 1*2 plot to show original, floor image,ceil image.
# Out:
# <class 'numpy.ndarray'>
# (256, 256)
# Text(0.5, 1.0, 'floor')

# %% [markdown]
# We can see unlike the rotation task we do not see any black dots here and the reason for that is this is a global translation meaning every point shifts a certain distance this means even if we use ceil or floor. Every point would still just shift to the closest pixel not leaving behind any spots.
#
# Translation of 3.75 with ceil() would become 4 and with floor() would become 3
#
# Translation of 4.3 with ceil() would become 5 and with floor() would become 4
#
# This means we already know that depending upon the approach the row or column which would be lost is in the left side and top side of the image as its a global shift of interger values.

# %%
total_pixels=data.shape[0]*data.shape[1]
base_zeros=np.count_nonzero(data==0)
holes2=np.count_nonzero(data2==0)-base_zeros
holes3=np.count_nonzero(data3==0)-base_zeros
print("total number of pixels in the image = ",total_pixels)
print("number of undefined pixels (for floor) = ",holes2," loss in image data (approx) = " ,holes2/total_pixels*100,"%")
print("number of undefined pixels (for ceil) = ",holes3," loss in image data (approx) = " ,holes3/total_pixels*100,"%")
#calculated the number of unassigned pixel in the target image and then saw the loss in data which is to say how many pixels now dont have information.
# Out:
# total number of pixels in the image =  65536
# number of undefined pixels (for floor) =  2284  loss in image data (approx) =  3.485107421875 %
# number of undefined pixels (for ceil) =  2284  loss in image data (approx) =  3.485107421875 %

# %% [markdown]
# This data loss metrics just shows how much have we moved from the center of the image as data loss is just in movement outside of out of bounds of the source image

# %% [markdown]
# In the next step we will be using Bi-linear interpolation using target to source transformation.
#
# This would mean the sign in the translation matrix would change to show a similar movement in image.

# %%
source=lena
data = asarray(source)
print(type(data))
print(data.shape)
#Opening up the image and making zero filled array of its size to store post processed image
data2=np.zeros_like(data)
for xt in range(data.shape[0]):
    for yt in range(data.shape[1]):
        #iterating through target co-ordinate
        xs=xt-tx
        ys=yt-ty
        #The translation leads to change in sign as we are now moving from target to source
        temp=bilin(xs,ys)
        #using bilinear interpolation function defined before.
        if (temp):
            data2[xt][yt]=temp
        
image=Image.fromarray(data)
image2 = Image.fromarray(data2)
#converted back the image from numpy array to Pillow image object to visualize.

figure, axis = plt.subplots(1, 2)
axis[0].imshow(image,cmap="gray")
axis[0].set_title('Original')
axis[1].imshow(image2,cmap="gray")
axis[1].set_title('Bilinear Interpolation')
#setting up a 1*2 plot to show original, floor image,ceil image.
# Out:
# <class 'numpy.ndarray'>
# (256, 256)
# Text(0.5, 1.0, 'Bilinear Interpolation')

# %% [markdown]
# In this we would not get much use out of bilinear interpolation as every point across the image would have moved only a certain distance meaning every point would have the same displacement from the neighbouring cells meaning each cell would have same a and b values in bilinear function.

# %% [markdown]
# Q3.Scale the given image (cells scale.png) by 0.8 and 1.3 factors?

# %%
a=0.8
b=0.8
#first we can start with scaling factor of 0.8 which means this will be a zoom out.

# %% [markdown]
# a<1 means Z is increasing that is the distance of the object from the optical axis this would mean we are doing a zoom out effect

# %%
source=cells
data = asarray(source)
print(type(data))
print(data.shape)
#again opening up the image and making zero filled array of its size to store post processed image
data2=np.zeros_like(data)
data3=np.zeros_like(data2)
offset_x=(data.shape[0]-a*data.shape[0])/2
offset_y=(data.shape[1]-b*data.shape[1])/2
#offset are calculated to keep the scaled image in the center by accounting for rows and column which now do not have any info
#this can be done by factoring the dimension of image with scaling factors and dividing by 2 to leave area equally on both sides.
for xs in range(data.shape[0]):
    for ys in range(data.shape[1]):
        #iterating through source co-ordinates.
        xt=xs*a
        yt=ys*b
        #adding translation to source co-ordinate
        if (xt<0 or yt<0 or xt>data.shape[0]-1 or yt>data.shape[1]-1):
            #to check for out of bounds issue as shifting would make some pixel move out of dimenstion of the image.
            continue
        
        #using ceil to resolve fractional co-ordinate issue here
        data2[math.ceil(xt+offset_x)][math.ceil(yt+offset_y)]=data[xs][ys]
        #adding the offset to keep image in center as it zooms out
        #using floor to resolve fractional co-ordinate issue here
        data3[math.floor(xt+offset_x)][math.floor(yt+offset_y)]=data[xs][ys]
        
image=Image.fromarray(data)
image2 = Image.fromarray(data2)
image3 = Image.fromarray(data3)
#converted back the image from numpy array to Pillow image object to visualize.

figure, axis = plt.subplots(1, 3)
axis[0].imshow(image,cmap="gray")
axis[0].set_title('Original')
axis[1].imshow(image2,cmap="gray")
axis[1].set_title('ceil')
axis[2].imshow(image3,cmap="gray")
axis[2].set_title('floor')
#setting up a 1*3 plot to show original, floor image,ceil image.
# Out:
# <class 'numpy.ndarray'>
# (240, 315)
# Text(0.5, 1.0, 'floor')

# %% [markdown]
# As expected we can see that image now holds lesser space in the image dimension than before as every co-ordinate has shrunk towards the center at a factor of 0.8 which would mean that image is now 80% of the image dimension but this means we have more empty pixel as we do not have knowledge about the outside of the original image space.

# %%
a=1.3
b=1.3

# %% [markdown]
# a>1 means Z is decreasing that is the distance of the object from the optical axis this would mean we are now moving towards the object hence zooming in or increases size of image.

# %%
source=cells
data = asarray(source)
print(type(data))
print(data.shape)
#again opening up the image and making zero filled array of its size to store post processed image
data2=np.zeros_like(data)
data3=np.zeros_like(data2)
for xs in range(data.shape[0]):
    for ys in range(data.shape[1]):
        #iterating through source co-ordinates.
        xt=xs*a
        yt=ys*b
        #adding translation to source co-ordinate
        if (xt<0 or yt<0 or xt>data.shape[0]-1 or yt>data.shape[1]-1):
            #to check for out of bounds issue as shifting would make some pixel move out of dimenstion of the image.
            continue
        
        #using ceil to resolve fractional co-ordinate issue here
        data2[math.ceil(xt)][math.ceil(yt)]=data[xs][ys]
        
        #using floor to resolve fractional co-ordinate issue here
        data3[math.floor(xt)][math.floor(yt)]=data[xs][ys]
        

image=Image.fromarray(data)
image2 = Image.fromarray(data2)
image3 = Image.fromarray(data3)
#converted back the image from numpy array to Pillow image object to visualize.

figure, axis = plt.subplots(1, 3)
axis[0].imshow(image,cmap="gray")
axis[0].set_title('Original')
axis[1].imshow(image2,cmap="gray")
axis[1].set_title('ceil')
axis[2].imshow(image3,cmap="gray")
axis[2].set_title('floor')
#setting up a 1*2 plot to show original, floor image,ceil image.
# Out:
# <class 'numpy.ndarray'>
# (240, 315)
# Text(0.5, 1.0, 'floor')

# %% [markdown]
# Here we are trying to get more details about the objects in the scene but as the information given by source image does not have these details we are left with a lot of black spots and lot of missing values which makes the image less detailed as well

# %%
total_pixels=data.shape[0]*data.shape[1]
base_zeros=np.count_nonzero(data==0)
holes2=np.count_nonzero(data2==0)-base_zeros
holes3=np.count_nonzero(data3==0)-base_zeros
print("total number of pixels in the image = ",total_pixels)
print("number of undefined pixels (for floor) = ",holes2," loss in image data (approx) = " ,holes2/total_pixels*100,"%")
print("number of undefined pixels (for ceil) = ",holes3," loss in image data (approx) = " ,holes3/total_pixels*100,"%")
#calculated the number of unassigned pixel in the target image and then saw the loss in data which is to say how many pixels now dont have information.
# Out:
# total number of pixels in the image =  75600
# number of undefined pixels (for floor) =  29978  loss in image data (approx) =  39.65343915343915 %
# number of undefined pixels (for ceil) =  29978  loss in image data (approx) =  39.65343915343915 %

# %% [markdown]
# We can the most data lost we got in any operation is in zooming in and it is obvious from the fact that in this case we are trying to fill original image space with details but we are only using about (1/1.3) of the original image data.

# %%
source=cells
data = asarray(source)
print(type(data))
print(data.shape)
#again opening up the image and making zero filled array of its size to store post processed image
data2=np.zeros_like(data)
zoom_at=(0,0)
for xt in range(data.shape[0]):
    for yt in range(data.shape[1]):
        #iterating through source co-ordinates.
        xs=xt/a
        ys=yt/b
        #adding translation to source co-ordinate
        if (xs<0 or ys<0 or xs>data.shape[0]-1 or ys>data.shape[1]-1):
            #to check for out of bounds issue as shifting would make some pixel move out of dimenstion of the image.
            continue
        #The translation leads to change in sign as we are now moving from target to source
        temp=bilin(xs,ys)
        #using bilinear interpolation function defined before.
        if (temp):
            data2[xt][yt]=temp
        
image=Image.fromarray(data)
image2 = Image.fromarray(data2)
image3 = Image.fromarray(data3)
#converted back the image from numpy array to Pillow image object to visualize.

figure, axis = plt.subplots(1, 3)
axis[0].imshow(image,cmap="gray")
axis[0].set_title('Original')
axis[1].imshow(image2,cmap="gray")
axis[1].set_title('Bilinear Interpolation')
axis[2].imshow(image3,cmap="gray")
axis[2].set_title('Simple floor or ceil')
#setting up a 1* plot to show original, floor image,ceil image.
# Out:
# <class 'numpy.ndarray'>
# (240, 315)
# Text(0.5, 1.0, 'Simple floor or ceil')

# %% [markdown]
# Bi-Linear Interpolation gives us way better results as a lot of missing points now have a point to influence its pixel value also this means we iterate through every point in target image so each point is assigned a relative weighted pixel value this does not gives up better details but smoothen the effect of lost information. Each pixel in target image is based only off 76% of information of the original image so we are increasing the resolution while decreasing the total information we have.

# %% [markdown]
# This would mean our image is now smoother but still do not incorporate extra details. This is a issue with zooming in and bi-linear interpolation can only help us so much.

# %%
# !pip install numpy
# !pip install pillow
# !pip install matplotlib
# !pip install sympy
# !pip install opencv-python
# Out:
# Requirement already satisfied: numpy in c:\python310\lib\site-packages (1.22.1)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pillow in c:\python310\lib\site-packages (9.0.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in c:\python310\lib\site-packages (3.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\python310\lib\site-packages (from matplotlib) (9.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python310\lib\site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib) (4.29.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\python310\lib\site-packages (from matplotlib) (1.22.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: sympy in c:\python310\lib\site-packages (1.9)
# Requirement already satisfied: mpmath>=0.19 in c:\python310\lib\site-packages (from sympy) (1.2.1)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: opencv-python in c:\python310\lib\site-packages (4.5.5.62)
# Requirement already satisfied: numpy>=1.21.2 in c:\python310\lib\site-packages (from opencv-python) (1.22.1)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from matplotlib import pyplot as plt
import random
# %matplotlib inline


plt.rcParams['figure.figsize'] = [18, 7]

# %%
from PIL import Image
from numpy import asarray
import cv2
import math
import numpy as np
from sympy import *
# load the image



img_1=cv2.imread('img1.png',0) 
img_2=cv2.imread('img2.png',0) 
img_3=cv2.imread('img3.png',0)

# %%
img_1.shape
# Out:
# (360, 640)

# %%
from sympy import *
def bilin(xs,ys,data):
        #This function takes fraction co-ordinate for source image based on target to source matrix and then uses bilinear interpolation to calculated the value of the given target co-ordinate
        xs_f=math.floor(xs)
        ys_f=math.floor(ys)
        a=ys-ys_f
        b=xs-xs_f
        #Above we calculate all necessary values to perform bilinear interpolation
        if (xs<0 or ys<0 or xs>data.shape[0]-2 or ys>data.shape[1]-2):
            #to account for the fact that this function may sometimes receive invalid co-ordinate such as negative or beyond image dimensions
            return False
        return (((1-a)*(1-b)*data[xs_f][ys_f])+
                ((a)*(1-b)*data[xs_f+1][ys_f])+
                ((1-a)*(b)*data[xs_f][ys_f+1])+
                ((a)*(b)*data[xs_f+1][ys_f+1]))
    

def homography(p1):
    a=np.empty((0,9))
    for i in range(len(p1)):
        x=p1[i][0]
        y=p1[i][1]
        a = np.append(a, np.array([[y[0],y[1],1,0,0,0,-1*(x[0]*y[0]),-1*(x[0]*y[1]),-x[0]]]), axis=0)
        a = np.append(a, np.array([[0,0,0,y[0],y[1],1,-1*(x[1]*y[0]),-1*(x[1]*y[1]),-x[1]]]), axis=0)
    #Creating numpy array to store A after this we will use sympy to solve for null space of this matrix
    A=Matrix(a)
    temp=A.nullspace()
    #temp is null matrix for A
    a=temp[0][0]
    b=temp[0][1]
    c=temp[0][2]
    d=temp[0][3]
    e=temp[0][4]
    f=temp[0][5]
    g=temp[0][6]
    h=temp[0][7]
    i=temp[0][8]
    # this assignment is based on the above equations

    h = np.array([[a,b,c], 
                  [d,e,f],
                  [g,h,i]])
    return Matrix(h)


def ransac(point_cor,dist,support_check,num_iter=20,debug=False):#[from][to]
    flag=True
    it=0
    if support_check>1:
        print("enter support<1")
        return False
    support=0
    while(flag):
        consensus=set()
        #Creating the A matrix which we will solve to find Homography for the given point correspondence
        a=np.empty((0,9))
        H=homography(random.sample(point_cor,4))
        H=np.float_(H)
        for i in point_cor:
            temp_x=np.matmul(H,np.array([i[1][0],i[1][1],1]))
            if temp_x[2]>1:
                temp_x[0]=temp_x[0]/temp_x[2]
                temp_x[1]=temp_x[1]/temp_x[2]
            d=np.sqrt(((i[0][0]-temp_x[0])**2)+((i[0][1]-temp_x[1])**2))
            if (d<dist):
                consensus.add(point_cor.index(i))
        if ((len(consensus)/len(point_cor))>support):
            support=len(consensus)/len(point_cor)
            if (support>support_check):
                return H,support
        it+=1
        if debug==True:
            print("Iteration :",it,"Consensus :",support)
        if it>num_iter:
            flag=False
            return H,support

# %%
data = asarray(img_1)
#casting the image as a numpy array and storing it in data
print(type(data))
print(data.shape)
print("Number of Pixels",data.shape[0]*data.shape[1])
# Out:
# <class 'numpy.ndarray'>
# (360, 640)
# Number of Pixels 230400

# %%
data = asarray(img_2)
#casting the image as a numpy array and storing it in data
print(type(data))
print(data.shape)
print("Number of Pixels",data.shape[0]*data.shape[1])
# Out:
# <class 'numpy.ndarray'>
# (360, 640)
# Number of Pixels 230400

# %%
data = asarray(img_3)
#casting the image as a numpy array and storing it in data
print(type(data))
print(data.shape)
print("Number of Pixels",data.shape[0]*data.shape[1])
# Out:
# <class 'numpy.ndarray'>
# (360, 640)
# Number of Pixels 230400

# %%
figure, axis = plt.subplots(1, 3)
axis[0].imshow(img_1,cmap="gray")
axis[0].set_title('IMG1')
axis[1].imshow(img_2,cmap="gray")
axis[1].set_title('IMG2')
axis[2].imshow(img_3,cmap="gray")
axis[2].set_title('IMG3')
# Out:
# Text(0.5, 1.0, 'IMG3')

# %%
data4=np.zeros((360, 1920))
data1 = asarray(img_1)
data2 = asarray(img_2)
data3 = asarray(img_3)
for x in range(data1.shape[0]-1):
    for y in range(data1.shape[1]-1):
        data4[x][y]=data1[x][y]
for x in range(data2.shape[0]-1):
    for y in range(data2.shape[1]-1):
        data4[x][y+640]=data2[x][y]
for x in range(data3.shape[0]-1):
    for y in range(data3.shape[1]-1):
        data4[x][y+1280]=data3[x][y]
plt.imshow(data4,cmap="gray")

# %%
#keypoints

sift_1 = cv2.SIFT_create()
kp_1,des_1 = sift_1.detectAndCompute(img_1,None)




#keypoints
sift_2 = cv2.SIFT_create()
kp_2,des_2 = sift_2.detectAndCompute(img_2,None)




#keypoints
sift_3 = cv2.SIFT_create()
kp_3,des_3 = sift_3.detectAndCompute(img_3,None)


img1=np.zeros((360,640))
img1 = cv2.drawKeypoints(img_1,kp_1,img1)

img2=np.zeros((360,640))
img2 = cv2.drawKeypoints(img_2,kp_2,img2)

img3=np.zeros((360,640))
img3 = cv2.drawKeypoints(img_3,kp_3,img3)

figure, axis = plt.subplots(1, 3)
axis[0].imshow(img1,cmap="gray")
axis[0].set_title('IMG1')
axis[1].imshow(img2,cmap="gray")
axis[1].set_title('IMG2')
axis[2].imshow(img3,cmap="gray")
axis[2].set_title('IMG3')
# Out:
# Text(0.5, 1.0, 'IMG3')

# %%
# create feature matcher
bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=False)
# match descriptors of both images
matches = bf.match(des_1,des_2)
# sort matches by distance
matches = sorted(matches, key = lambda x:x.distance)
# draw first 10 matches
matched_img = cv2.drawMatches(img_1, kp_1, img_2, kp_2, matches[:10], img_2, flags=2)
plt.imshow(matched_img)

# %%
list_kp21 = [(kp_1[mat.queryIdx].pt,kp_2[mat.trainIdx].pt) for mat in matches[:40]] 
H21=homography(random.sample(list_kp21,4))

# %%
H21
# Out:
# Matrix([
# [    0.815265713217741,    0.315989869144953, 146.921570364919],
# [  -0.0899948990952329,      1.1340103136438, 12.6070900743885],
# [-0.000444464785437498, 0.000597443245987919,                1]])

# %%
H21,support=ransac(list_kp21,5,0.8,1000,debug=True)
# Out:
# Iteration : 1 Consensus : 0
# Iteration : 2 Consensus : 0
# Iteration : 3 Consensus : 0
# Iteration : 4 Consensus : 0.025
# Iteration : 5 Consensus : 0.05
# Iteration : 6 Consensus : 0.05
# Iteration : 7 Consensus : 0.05
# Iteration : 8 Consensus : 0.05
# Iteration : 9 Consensus : 0.05
# Iteration : 10 Consensus : 0.175
# Iteration : 11 Consensus : 0.175
# Iteration : 12 Consensus : 0.175
# Iteration : 13 Consensus : 0.175
# Iteration : 14 Consensus : 0.175
# Iteration : 15 Consensus : 0.175
# Iteration : 16 Consensus : 0.175
# Iteration : 17 Consensus : 0.175
# Iteration : 18 Consensus : 0.175
# Iteration : 19 Consensus : 0.175
# Iteration : 20 Consensus : 0.175
# Iteration : 21 Consensus : 0.175
# Iteration : 22 Consensus : 0.45
# Iteration : 23 Consensus : 0.45
# Iteration : 24 Consensus : 0.45
# Iteration : 25 Consensus : 0.45
# Iteration : 26 Consensus : 0.45
# Iteration : 27 Consensus : 0.45
# Iteration : 28 Consensus : 0.45
# Iteration : 29 Consensus : 0.45
# Iteration : 30 Consensus : 0.45
# Iteration : 31 Consensus : 0.45
# Iteration : 32 Consensus : 0.45
# Iteration : 33 Consensus : 0.45
# Iteration : 34 Consensus : 0.45
# Iteration : 35 Consensus : 0.45
# Iteration : 36 Consensus : 0.45
# Iteration : 37 Consensus : 0.45
# Iteration : 38 Consensus : 0.45
# Iteration : 39 Consensus : 0.45
# Iteration : 40 Consensus : 0.45
# Iteration : 41 Consensus : 0.45
# Iteration : 42 Consensus : 0.45
# Iteration : 43 Consensus : 0.45
# Iteration : 44 Consensus : 0.45
# Iteration : 45 Consensus : 0.45
# Iteration : 46 Consensus : 0.45
# Iteration : 47 Consensus : 0.45
# Iteration : 48 Consensus : 0.45
# Iteration : 49 Consensus : 0.45
# Iteration : 50 Consensus : 0.45
# Iteration : 51 Consensus : 0.45
# Iteration : 52 Consensus : 0.45
# Iteration : 53 Consensus : 0.45
# Iteration : 54 Consensus : 0.45
# Iteration : 55 Consensus : 0.45
# Iteration : 56 Consensus : 0.45
# Iteration : 57 Consensus : 0.45
# Iteration : 217 Consensus : 0.7
# Iteration : 218 Consensus : 0.7
# Iteration : 219 Consensus : 0.7
# Iteration : 220 Consensus : 0.7
# Iteration : 221 Consensus : 0.7
# Iteration : 222 Consensus : 0.7
# Iteration : 223 Consensus : 0.7
# Iteration : 224 Consensus : 0.7
# Iteration : 225 Consensus : 0.7
# Iteration : 226 Consensus : 0.7
# Iteration : 227 Consensus : 0.7
# Iteration : 228 Consensus : 0.7
# Iteration : 229 Consensus : 0.7
# Iteration : 230 Consensus : 0.7
# Iteration : 231 Consensus : 0.7
# Iteration : 232 Consensus : 0.7
# Iteration : 233 Consensus : 0.7
# Iteration : 234 Consensus : 0.7
# Iteration : 235 Consensus : 0.7
# Iteration : 236 Consensus : 0.7
# Iteration : 237 Consensus : 0.7
# Iteration : 238 Consensus : 0.7
# Iteration : 239 Consensus : 0.7
# Iteration : 240 Consensus : 0.7
# Iteration : 241 Consensus : 0.7
# Iteration : 242 Consensus : 0.7
# Iteration : 243 Consensus : 0.7
# Iteration : 244 Consensus : 0.7
# Iteration : 245 Consensus : 0.7
# Iteration : 246 Consensus : 0.7
# Iteration : 247 Consensus : 0.7
# Iteration : 248 Consensus : 0.7
# Iteration : 249 Consensus : 0.7
# Iteration : 250 Consensus : 0.7
# Iteration : 251 Consensus : 0.7
# Iteration : 252 Consensus : 0.7
# Iteration : 253 Consensus : 0.7
# Iteration : 254 Consensus : 0.7
# Iteration : 255 Consensus : 0.7
# Iteration : 256 Consensus : 0.7
# Iteration : 257 Consensus : 0.7
# Iteration : 258 Consensus : 0.7
# Iteration : 259 Consensus : 0.7
# Iteration : 260 Consensus : 0.7
# Iteration : 261 Consensus : 0.7
# Iteration : 262 Consensus : 0.7
# Iteration : 263 Consensus : 0.7
# Iteration : 264 Consensus : 0.7
# Iteration : 265 Consensus : 0.7
# Iteration : 266 Consensus : 0.7
# Iteration : 267 Consensus : 0.7
# Iteration : 268 Consensus : 0.7
# Iteration : 269 Consensus : 0.7
# Iteration : 270 Consensus : 0.7
# Iteration : 271 Consensus : 0.7
# Iteration : 272 Consensus : 0.7
# Iteration : 273 Consensus : 0.7
# Iteration : 274 Consensus : 0.7
# Iteration : 275 Consensus : 0.7
# Iteration : 276 Consensus : 0.7
# Iteration : 277 Consensus : 0.7
# Iteration : 278 Consensus : 0.7
# Iteration : 279 Consensus : 0.7
# Iteration : 280 Consensus : 0.7
# Iteration : 281 Consensus : 0.7
# Iteration : 282 Consensus : 0.7
# Iteration : 283 Consensus : 0.7
# Iteration : 284 Consensus : 0.7
# Iteration : 285 Consensus : 0.7
# Iteration : 286 Consensus : 0.7
# Iteration : 287 Consensus : 0.7
# Iteration : 288 Consensus : 0.7
# Iteration : 289 Consensus : 0.7
# Iteration : 290 Consensus : 0.7
# Iteration : 291 Consensus : 0.7
# Iteration : 292 Consensus : 0.7
# Iteration : 293 Consensus : 0.7
# Iteration : 294 Consensus : 0.7
# Iteration : 295 Consensus : 0.7
# match descriptors of both images
matches = bf.match(des_3,des_2)
# sort matches by distance
matches = sorted(matches, key = lambda x:x.distance)
# draw first 50 matches
matched_img = cv2.drawMatches(img_3, kp_3, img_2, kp_2, matches[:4], img_2, flags=2)
plt.imshow(matched_img)

# %%
list_kp23 = [(kp_3[mat.queryIdx].pt,kp_2[mat.trainIdx].pt) for mat in matches[:50]] 
H23=homography(random.sample(list_kp23,4))

# %%
H23
# Out:
# Matrix([
# [   -4.34630284175365,   -0.171972396007078, 1310.11211125901],
# [   -1.33008866672762,    -2.99369268766274, 610.190262186358],
# [-0.00873492031231454, -0.00162844506080083,                1]])

# %%
H23,support=ransac(list_kp23,5,0.8,1000,debug=True)
# Out:
# Iteration : 1 Consensus : 0.62

# %%
H23
# Out:
# array([[ 1.53082205e+00, -3.85498259e-02, -3.89338171e+02],
#        [ 1.37938756e-01,  1.35137451e+00, -7.93906398e+01],
#        [ 8.24147005e-04, -4.05229286e-05,  1.00000000e+00]])

# %%
support
# Out:
# 0.96

# %%
from PIL import Image
from numpy import asarray

# load the image
img_1 = asarray(Image.open('img1.png'))
img_2 = asarray(Image.open('img2.png'))
img_3 = asarray(Image.open('img3.png'))

# %%
figure, axis = plt.subplots(1, 3)
axis[0].imshow(img_1,cmap="gray")
axis[0].set_title('IMG1')
axis[1].imshow(img_2,cmap="gray")
axis[1].set_title('IMG2')
axis[2].imshow(img_3,cmap="gray")
axis[2].set_title('IMG3')
# Out:
# Text(0.5, 1.0, 'IMG3')

# %%
canvas=np.zeros((1080,1920))
offset=[300,300]
v=[]
for y_s in range(canvas.shape[0]-1):
    for x_s in range(canvas.shape[1]-1):
        v=[]
        x=x_s-offset[0]
        y=y_s-offset[1]
        
        tmp=np.matmul(H21,[x,y,1])
        tmp[0]=tmp[0]/tmp[2]
        tmp[1]=tmp[1]/tmp[2]
        v.append(bilin(tmp[1],tmp[0],img_1))
        
        tmp=np.matmul(H23,[x,y,1])
        tmp[0]=tmp[0]/tmp[2]
        tmp[1]=tmp[1]/tmp[2]
        v.append(bilin(tmp[1],tmp[0],img_3))
        
        v.append(bilin(y,x,img_2))

        
        if v.count(False)>2:
            continue
        canvas[y_s][x_s]=sum(v)/(3-v.count(False))

# %%
plt.imshow(canvas,cmap="gray")

# %%
canvas=np.zeros((550,1400))
offset=[300,100]
for x_s in range(canvas.shape[1]):
    for y_s in range(canvas.shape[0]):
        v=[]
        x=x_s-offset[0]
        y=y_s-offset[1]
        x21=np.matmul(H21,[x,y,1])
        x21[0]=x21[0]/x21[2]
        x21[1]=x21[1]/x21[2]
        v.append(bilin(x21[1],x21[0],img_1))
        v.append(bilin(y,x,img_2))
        x23=np.matmul(H23,[x,y,1])
        x23[0]=x23[0]/x23[2]
        x23[1]=x23[1]/x23[2]
        v.append(bilin(x23[1],x23[0],img_3))
        
        if v.count(False)>2:
            continue
        canvas[y_s][x_s]=sum(v)/(3-v.count(False))

# %%
plt.imshow(canvas,cmap="gray")

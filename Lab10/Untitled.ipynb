# %%
from PIL import Image
import math
import numpy as np
import matplotlib.pyplot as plt
import cv2

plt.rcParams['figure.figsize'] = [18, 7]

# %%
krishna=cv2.cvtColor(cv2.imread("krishna.png"), cv2.COLOR_BGR2RGB)
krishna_0_001=cv2.cvtColor(cv2.imread("krishna_0_001.png"), cv2.COLOR_BGR2RGB)

# %%
figure, axis = plt.subplots(1, 2)
axis[0].imshow(krishna)
axis[0].set_title('krishna')
axis[1].imshow(krishna_0_001)
axis[1].set_title('krishna_0_001 ')
# Out:
# Text(0.5, 1.0, 'krishna_0_001 ')
